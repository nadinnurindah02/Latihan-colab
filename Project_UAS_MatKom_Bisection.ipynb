# %% [markdown]
# <a href="https://colab.research.google.com/github/nadinnurindah02/Latihan-colab/blob/main/Project_UAS_MatKom_Bisection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # PROJECT UAS MATEMATIKA KOMPUTASI
#
# ## Aplikasi Metode Bisection untuk Menentukan Akar Persamaan Nonlinier
#
#
# Nama Kelompok:
# 1. Nadin Nur Indah
# 2. Destiana Lingga Sari
# 3. Rezza Ramadani
#
# ## Tujuan Project
#
# Project ini bertujuan untuk membuat aplikasi yang dapat digunakan untuk menentukan akar persamaan nonlinier menggunakan Metode Bisection.
#
# Pengguna dapat memasukkan fungsi yang ingin dicari akarnya, kemudian aplikasi akan menghitung akar persamaan, jumlah iterasi, serta menampilkan proses perhitungan dan grafiknya.

# %%
# Import Library

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# Penjelasan Library
#
# NumPy digunakan untuk membantu perhitungan numerik.
#
# Pandas digunakan untuk membuat tabel hasil iterasi agar lebih mudah dibaca.
#
# Matplotlib digunakan untuk membuat grafik fungsi sehingga akar persamaan dapat dilihat secara visual.

# %%
# Input Data dari Pengguna
fungsi = input("Masukkan fungsi yang ingin dicari akarnya: ")

batas_bawah = float(input("Masukkan batas bawah interval: "))

batas_atas = float(input("Masukkan batas atas interval: "))

toleransi = float(input("Masukkan tingkat ketelitian yang diinginkan: "))
# Out:
# Masukkan fungsi yang ingin dicari akarnya: x**3-4*x-9
# Masukkan batas bawah interval: 2
# Masukkan batas atas interval: 3
# Masukkan tingkat ketelitian yang diinginkan: 0.0001

# %% [markdown]
# Penjelasan Input
#
# Fungsi adalah persamaan yang akan dicari akarnya.
#
# Batas bawah dan batas atas digunakan sebagai interval awal pencarian akar.
#
# Tingkat ketelitian (toleransi) digunakan untuk menentukan kapan proses iterasi dihentikan.
# Semakin kecil nilainya, semakin teliti hasil yang diperoleh.

# %%
# Membuat Fungsi Matematika
def hitung_fungsi(x):
    return eval(fungsi)

# %% [markdown]
# ## Penjelasan Fungsi
#
# Fungsi ini digunakan untuk menghitung nilai fungsi yang dimasukkan pengguna.
#
# Sebagai contoh, jika fungsi yang dimasukkan adalah x**3 - 2*x - 5, maka program dapat menghitung nilai fungsi tersebut pada setiap nilai x yang diperlukan.

# %%
# Memeriksa Syarat Metode Bisection
if hitung_fungsi(batas_bawah) * hitung_fungsi(batas_atas) > 0:
    print("Interval yang dimasukkan tidak memenuhi syarat Metode Bisection")
else:
    print("Interval memenuhi syarat")
# Out:
# Interval memenuhi syarat

# %% [markdown]
# ## Validasi Interval
#
# Metode Bisection mensyaratkan bahwa fungsi pada batas bawah dan batas atas memiliki tanda yang berbeda.
#
# Jika syarat ini tidak terpenuhi, maka proses pencarian akar tidak dapat dilakukan.

# %%
# Perhitungan Metode Bisection

data_iterasi = []

jumlah_iterasi = 0

while abs(batas_atas - batas_bawah) > toleransi:

    titik_tengah = (batas_bawah + batas_atas) / 2

    data_iterasi.append([
        jumlah_iterasi + 1,
        batas_bawah,
        batas_atas,
        titik_tengah
    ])

    if hitung_fungsi(batas_bawah) * hitung_fungsi(titik_tengah) < 0:
        batas_atas = titik_tengah
    else:
        batas_bawah = titik_tengah

    jumlah_iterasi += 1

akar = (batas_bawah + batas_atas) / 2

print("Akar persamaan =", akar)

print("Jumlah iterasi =", jumlah_iterasi)
# Out:
# Akar persamaan = 2.706512451171875
# Jumlah iterasi = 14

# %% [markdown]
# ## Melakukan Perhitungan Metode Bisection
#
# Pada bagian ini program melakukan proses pencarian akar secara berulang sampai diperoleh hasil yang memenuhi tingkat ketelitian yang diinginkan.

# %%
# Menampilkan Tabel Iterasi

tabel_iterasi = pd.DataFrame(
    data_iterasi,
    columns=[
        "Iterasi",
        "Batas Bawah",
        "Batas Atas",
        "Titik Tengah"
    ]
)

tabel_iterasi
# Out:
#     Iterasi  Batas Bawah  Batas Atas  Titik Tengah
# 0         1     2.000000    3.000000      2.500000
# 1         2     2.500000    3.000000      2.750000
# 2         3     2.500000    2.750000      2.625000
# 3         4     2.625000    2.750000      2.687500
# 4         5     2.687500    2.750000      2.718750
# 5         6     2.687500    2.718750      2.703125
# 6         7     2.703125    2.718750      2.710938
# 7         8     2.703125    2.710938      2.707031
# 8         9     2.703125    2.707031      2.705078
# 9        10     2.705078    2.707031      2.706055
# 10       11     2.706055    2.707031      2.706543
# 11       12     2.706055    2.706543      2.706299
# 12       13     2.706299    2.706543      2.706421
# 13       14     2.706421    2.706543      2.706482

# %%
# Menampilkan Grafik Fungsi

x = np.linspace(batas_bawah - 2, batas_atas + 2, 400)
y = [hitung_fungsi(nilai_x) for nilai_x in x]

plt.figure(figsize=(8,5))
plt.plot(x, y)
plt.axhline(y=0)

plt.title("Grafik Fungsi")
plt.xlabel("Nilai x")
plt.ylabel("Nilai f(x)")
plt.grid()
plt.show()

# %% [markdown]
# ## Interpretasi
# Berdasarkan hasil perhitungan, Metode Bisection berhasil menentukan akar persamaan nonlinier sesuai tingkat ketelitian yang diberikan.
#
# Program juga menampilkan tabel iterasi dan grafik fungsi sehingga proses pencarian akar dapat diamati dengan lebih mudah.
